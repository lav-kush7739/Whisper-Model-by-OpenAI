# %% [markdown]
# <a href="https://colab.research.google.com/github/lav-kush7739/Whisper-Model-by-OpenAI/blob/main/NLP_OpenAI_Whisper_ASR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Install the Whisper Code

# %% [markdown]
# Credits : https://github.com/openai/whisper

# %%
! pip install git+https://github.com/openai/whisper.git -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 28.4 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.

# %% [markdown]
# ## Load the ML Model

# %%
import whisper

model = whisper.load_model("small")
# Out:
# 100%|███████████████████████████████████████| 461M/461M [00:07<00:00, 64.9MiB/s]

# %% [markdown]
# ## Check we have a GPU
#
# You should see the output `device(type='cuda', index=0)` below. If you don't, you may be on a CPU-only Colab instance which will run more slowly. Go to `Runtime->Change Runtime Type` to fix this.

# %%
model.device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# ## Download Test Audio Files
#
# This repository has a couple of pre-recorded MP3s to run through the transcribe function. You can listen to them with the audio widgets displayed below.

# %%
# !git clone https://github.com/petewarden/openai-whisper-webapp
# Out:
# Cloning into 'openai-whisper-webapp'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 33 (delta 12), reused 5 (delta 1), pack-reused 0
# Receiving objects: 100% (33/33), 1.40 MiB | 3.80 MiB/s, done.
# Resolving deltas: 100% (12/12), done.

# %%
from IPython.display import Audio
Audio("/content/openai-whisper-webapp/mary.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import Audio
Audio("/content/openai-whisper-webapp/daisy_HAL_9000.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# PyDub can be used to convert audio files from one format to another.

# %%
# !pip install pydub

# %%
from google.colab import files

# Upload the audio file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-62a3fb6a-2ff6-4660-88af-2a3b1cab2311" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-62a3fb6a-2ff6-4660-88af-2a3b1cab2311">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

# List files in the /content directory
content_dir = '/content'
files_in_content = os.listdir(content_dir)

# Display the list of files
print("Files in /content directory:")
for file_name in files_in_content:
    print(file_name)
# Out:
# Files in /content directory:
# .config
# sample_data

# %%
#uploaded_file_name = "hemant_kumar.mp3"
uploaded_file_name = "/hemant_kumar.mp3"
uploaded_file_path = os.path.join(content_dir, uploaded_file_name)

print("Path to the uploaded file:")
print(uploaded_file_path)
# Out:
# Path to the uploaded file:
# /hemant_kumar.mp3

# %%
from IPython.display import Audio

# Use forward slashes in the file path
#audio_path = "/content/hemant_kumar.mp3"
audio_path="/hemant_kumar.mp3"

Audio(audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Define the Transcribe Function
#
# Now we've loaded the model, and have the code, this is the function that takes an audio file path as an input and returns the recognized text (and logs what it thinks the language is).

# %%
def transcribe(audio):

    # load audio and pad/trim it to fit 30 seconds
    audio = whisper.load_audio(audio)
    audio = whisper.pad_or_trim(audio)

    # make log-Mel spectrogram and move to the same device as the model
    mel = whisper.log_mel_spectrogram(audio).to(model.device)

    # detect the spoken language
    _, probs = model.detect_language(mel)
    print(f"Detected language: {max(probs, key=probs.get)}")

    # decode the audio
    options = whisper.DecodingOptions()
    result = whisper.decode(model, mel, options)
    return result.text

# %%
# duplicate
def transcribe(audio):

    # load audio and pad/trim it to fit 30 seconds
    audio = whisper.load_audio(audio)
    audio = whisper.pad_or_trim(audio)

    # make log-Mel spectrogram and move to the same device as the model
    mel = whisper.log_mel_spectrogram(audio).to(model.device)

    # detect the spoken language
    _, probs = model.detect_language(mel)
    print(f"Detected language: {max(probs, key=probs.get)}")

    # decode the audio
    {"fp16": False, "language": "en", "task": "transcribe"}
    result = whisper.decode(model, mel, options)
    return result.text

# %%
pip install googletrans==4.0.0-rc1
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 8.1 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17396 sha256=70f7b7e7ec623ad18dca46d298e0cc6780ecd23582f49cfd1879794ddfbe233e
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# ...
#   Attempting uninstall: chardet
# ...

# %%
#DUPLICATE2-OPENAI
import whisper

def transcribe_to_english(audio):
    # Load audio and pad/trim it to fit 30 seconds
    audio = whisper.load_audio(audio)
    audio = whisper.pad_or_trim(audio)

    # Make log-Mel spectrogram and move to the same device as the model
    mel = whisper.log_mel_spectrogram(audio).to(model.device)

    # Decode the audio
    options = whisper.DecodingOptions()
    result = whisper.decode(model, mel, options)

    # You can add logic here to detect the language if needed
    # and handle cases where it's not English

    # Return the transcribed text as is
    return result.text

# Provide the path to the audio file you want to transcribe
audio_path = "/content/hemant_kumar.mp3"

# Call the transcribe_to_english function and get the transcribed text
transcribed_text = transcribe_to_english(audio_path)

# Print or use the transcribed text as needed
print("Transcribed Text (Always in English):")
print(transcribed_text)


# Provide the path to the audio file you want to transcribe
audio_path = "/content/hemant_kumar.mp3"

# Call the transcribe_and_translate_to_english function and get the transcribed text
transcribed_text = transcribe_and_translate_to_english(audio_path)

# Print or use the transcribed text as needed
print("Transcribed Text (Always in English):")
print(transcribed_text)
# Out:
# Transcribed Text (Always in English):
# जाने उ कैसे लोग थे जिनके प्यार को प्यार मिला जाने उ कैसे लोग थे जिनके प्यार को प्यार मिला
# Transcribed Text (Always in English):
# Know how they were people whose love was found, how people were people whose love got love

# %%
def transcribe(audio):

    # load audio and pad/trim it to fit 30 seconds
    audio = whisper.load_audio(audio)
    audio = whisper.pad_or_trim(audio)

    # make log-Mel spectrogram and move to the same device as the model
    mel = whisper.log_mel_spectrogram(audio).to(model.device)

    # decode the audio
    options = whisper.DecodingOptions()
    result = whisper.decode(model, mel, options)

    return result.text

# Provide the path to the audio file you want to transcribe
audio_path = "/hemant_kumar.mp3"

# Call the transcribe function and get the transcribed text
transcribed_text = transcribe(audio_path)

# Print or use the transcribed text as needed
print("Transcribed Text:")
print(transcribed_text)
# Out:
# Transcribed Text:
# जाने उ कैसे लोग थे जिनके प्यार को प्यार मिला जाने उ कैसे लोग थे जिनके प्यार को प्यार मिला

# %%
# COPY OF MODULE WHICH CALLS THE TRANSCRIBE FUNCTION

def transcribe(audio):

    # load audio and pad/trim it to fit 30 seconds
    audio = whisper.load_audio(audio)
    audio = whisper.pad_or_trim(audio)

    # make log-Mel spectrogram and move to the same device as the model
    mel = whisper.log_mel_spectrogram(audio).to(model.device)

    # decode the audio
    options = whisper.DecodingOptions()
    result = whisper.decode(model, mel, options)

    return result.text

# Provide the path to the audio file you want to transcribe
audio_path = "/content/hemant_kumar.mp3"

# Call the transcribe function and get the transcribed text
transcribed_text = transcribe_and_translate_to_english(audio_path)

# Print or use the transcribed text as needed
print("Transcribed Text:")
print(transcribed_text)
# Out:
# Transcribed Text:
# Know how they were people whose love was found, how people were people whose love got love

# %% [markdown]
# ## Test with Pre-Recorded Audio
#
# Before we bring up the UI to allow you to record your own live audio, we're going to run the `transcribe()` function on a couple of MP3s we've downloaded. You should see `Mary had a little lamb, its fleece was white as snow, and everywhere that Mary went, the lamb was sure to go.` for `mary.mp3`, which I recorded as an example of clear audio. The second file is a lot harder to transcribe, with very distorted audio, but the model does a good job with `Tazy, Tazy, Tazy. Give me your answer to time after crazy all for the love of you. It won't be a stylish marriage`. You'll notice the transcript is cut off after 30 seconds, which is the default length for this notebook. It can be extended, but that's outside of the scope of this documentation.

# %%
easy_text = transcribe("/content/hemant_kumar.mp3")
print(easy_text)

#hard_text = transcribe("/content/openai-whisper-webapp/daisy_HAL_9000.mp3")
#print(hard_text)
# Out:
# Detected language: hi
# जाने उ कैसे लोग थे जिनके प्यार को प्यार मिला जाने उ कैसे लोग थे जिनके प्यार को प्यार मिला

# %% [markdown]
# ## Install the Web UI Toolkit
#
# We'll be using gradio to provide the widgets we need to do audio recording.

# %%
! pip install gradio -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.2/20.2 MB 68.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.2/298.2 kB 30.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.7/75.7 kB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 29.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 15.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 14.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 7.8 MB/s eta 0:00:00
# ...

# %%
import gradio as gr
import time

# %% [markdown]
# ## Web Interface
#
# After running this script, you should see two widgets below that you can use to record live audio and see the transcription, as described in the introduction.

# %%
gr.Interface(
    title = 'OpenAI Whisper ASR Gradio Web UI',
    fn=transcribe,
    inputs=[
        gr.inputs.Audio(source="microphone", type="filepath")
    ],
    outputs=[
        "textbox"
    ],
    live=True).launch()
# Out:
# <ipython-input-24-391fc86502e4>:5: GradioDeprecationWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   gr.inputs.Audio(source="microphone", type="filepath")
# <ipython-input-24-391fc86502e4>:5: GradioDeprecationWarning: `optional` parameter is deprecated, and it has no effect
#   gr.inputs.Audio(source="microphone", type="filepath")
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.
